# %%
# Import Dep
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time# Imports and requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
from citipy import citipy
from datetime import datetime
from scipy.stats import linregress
#Import the requests library
import requests
#Import the API key.
from config import weather_api_key

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description
                        })

# If an error is experienced, skip the city.
    except KeyError:
            print("City not found. Skipping...")
            pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | wewak
# Processing Record 3 of Set 1 | belmonte
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | tambopata
# Processing Record 6 of Set 1 | aksu
# Processing Record 7 of Set 1 | victoria
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | saquarema
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | bredasdorp
# Processing Record 14 of Set 1 | sena madureira
# Processing Record 15 of Set 1 | lavrentiya
# Processing Record 16 of Set 1 | xingyi
# Processing Record 17 of Set 1 | saint george
# Processing Record 18 of Set 1 | oeiras do para
# Processing Record 19 of Set 1 | torbay
# Processing Record 20 of Set 1 | qaanaaq
# Processing Record 21 of Set 1 | kodiak
# Processing Record 22 of Set 1 | airai
# Processing Record 23 of Set 1 | nishihara
# Processing Record 24 of Set 1 | hobart
# Processing Record 25 of Set 1 | aukra
# Processing Record 26 of Set 1 | hihifo
# City not found. Skipping...
# Processing Record 27 of Set 1 | sisimiut
# Processing Record 28 of Set 1 | abomsa
# Processing Record 29 of Set 1 | wulanhaote
# City not found. Skipping...
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | east london
# Processing Record 32 of Set 1 | verkhnevilyuysk
# Processing Record 33 of Set 1 | hami
# Processing Record 34 of Set 1 | tasiilaq
# Processing Record 35 of Set 1 | rikitea
# Processing Record 36 of Set 1 | newport
# Processing Record 37 of Set 1 | port elizabeth
# Processing Record 38 of Set 1 | maceio
# Processing Record 39 of Set 1 | bengkulu
# Processing Record 40 of Set 1 | kudahuvadhoo
# Processing Record 41 of Set 1 | hilo
# Processing Record 42 of Set 1 | saint anthony
# Processing Record 43 of Set 1 | krasnoselkup
# Processing Record 44 of Set 1 | butaritari
# Processing Record 45 of Set 1 | jamestown
# Processing Record 46 of Set 1 | dikson
# Processing Record 47 of Set 1 | mabaruma
# Processing Record 48 of Set 1 | ushuaia
# Processing Record 49 of Set 1 | tire
# Processing Record 50 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 1 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 2 | khatanga
# Processing Record 3 of Set 2 | santa isabel do rio negro
# Processing Record 4 of Set 2 | san quintin
# Processing Record 5 of Set 2 | new norfolk
# Processing Record 6 of Set 2 | sangueya
# Processing Record 7 of Set 2 | tiksi
# Processing Record 8 of Set 2 | kruisfontein
# Processing Record 9 of Set 2 | iskateley
# Processing Record 10 of Set 2 | dubbo
# Processing Record 11 of Set 2 | tarudant
# City not found. Skipping...
# Processing Record 12 of Set 2 | aykhal
# Processing Record 13 of Set 2 | muroto
# Processing Record 14 of Set 2 | ribeira grande
# Processing Record 15 of Set 2 | codo
# Processing Record 16 of Set 2 | hithadhoo
# Processing Record 17 of Set 2 | port alfred
# Processing Record 18 of Set 2 | coihaique
# Processing Record 19 of Set 2 | kanniyakumari
# Processing Record 20 of Set 2 | codrington
# Processing Record 21 of Set 2 | solnechnyy
# Processing Record 22 of Set 2 | tunduru
# City not found. Skipping...
# Processing Record 23 of Set 2 | kaitangata
# Processing Record 24 of Set 2 | saskylakh
# Processing Record 25 of Set 2 | vila
# Processing Record 26 of Set 2 | san lorenzo
# Processing Record 27 of Set 2 | ericeira
# Processing Record 28 of Set 2 | bluff
# Processing Record 29 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 2 | kununurra
# Processing Record 31 of Set 2 | saldanha
# Processing Record 32 of Set 2 | inhambane
# Processing Record 33 of Set 2 | iquique
# Processing Record 34 of Set 2 | nikolskoye
# Processing Record 35 of Set 2 | fortuna
# Processing Record 36 of Set 2 | avarua
# Processing Record 37 of Set 2 | yellowknife
# Processing Record 38 of Set 2 | clovis
# Processing Record 39 of Set 2 | mount isa
# Processing Record 40 of Set 2 | celestun
# Processing Record 41 of Set 2 | glendive
# Processing Record 42 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 2 | georgetown
# Processing Record 44 of Set 2 | puerto ayora
# Processing Record 45 of Set 2 | portland
# Processing Record 46 of Set 2 | esperance
# Processing Record 47 of Set 2 | changping
# Processing Record 48 of Set 2 | carnarvon
# Processing Record 49 of Set 2 | souillac
# Processing Record 50 of Set 2 | oranjemund
# Processing Record 1 of Set 3 | artyom
# Processing Record 2 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 3 | tiznit
# Processing Record 4 of Set 3 | nueve de julio
# Processing Record 5 of Set 3 | lerwick
# Processing Record 6 of Set 3 | santiago de cao
# Processing Record 7 of Set 3 | chuy
# Processing Record 8 of Set 3 | ibotirama
# Processing Record 9 of Set 3 | kibuye
# Processing Record 10 of Set 3 | san carlos de bariloche
# Processing Record 11 of Set 3 | brae
# Processing Record 12 of Set 3 | vestmannaeyjar
# Processing Record 13 of Set 3 | leningradskiy
# Processing Record 14 of Set 3 | tuatapere
# Processing Record 15 of Set 3 | port blair
# Processing Record 16 of Set 3 | muros
# Processing Record 17 of Set 3 | hvolsvollur
# Processing Record 18 of Set 3 | talnakh
# Processing Record 19 of Set 3 | thompson
# Processing Record 20 of Set 3 | srednekolymsk
# Processing Record 21 of Set 3 | narok
# Processing Record 22 of Set 3 | maloy
# Processing Record 23 of Set 3 | long beach
# Processing Record 24 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 3 | emerald
# Processing Record 26 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 3 | kieta
# Processing Record 28 of Set 3 | shenjiamen
# Processing Record 29 of Set 3 | arrifes
# Processing Record 30 of Set 3 | manzanillo
# Processing Record 31 of Set 3 | tuktoyaktuk
# Processing Record 32 of Set 3 | zyryanka
# Processing Record 33 of Set 3 | vila velha
# Processing Record 34 of Set 3 | barrow
# Processing Record 35 of Set 3 | tura
# Processing Record 36 of Set 3 | rio grande
# Processing Record 37 of Set 3 | gorontalo
# Processing Record 38 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 3 | mahibadhoo
# Processing Record 40 of Set 3 | clyde river
# Processing Record 41 of Set 3 | pasni
# Processing Record 42 of Set 3 | wladyslawowo
# Processing Record 43 of Set 3 | gamba
# Processing Record 44 of Set 3 | laguna
# Processing Record 45 of Set 3 | ahipara
# Processing Record 46 of Set 3 | vila franca do campo
# Processing Record 47 of Set 3 | ilulissat
# Processing Record 48 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 3 | batouri
# Processing Record 50 of Set 3 | norman wells
# Processing Record 1 of Set 4 | port-gentil
# Processing Record 2 of Set 4 | albany
# Processing Record 3 of Set 4 | upernavik
# Processing Record 4 of Set 4 | mizpe ramon
# City not found. Skipping...
# Processing Record 5 of Set 4 | gari
# Processing Record 6 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 4 | biloela
# Processing Record 8 of Set 4 | namatanai
# Processing Record 9 of Set 4 | bethel
# Processing Record 10 of Set 4 | goba
# Processing Record 11 of Set 4 | gat
# Processing Record 12 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 4 | shirokiy
# Processing Record 14 of Set 4 | kuopio
# Processing Record 15 of Set 4 | nizhniy bestyakh
# Processing Record 16 of Set 4 | asau
# Processing Record 17 of Set 4 | richards bay
# Processing Record 18 of Set 4 | mantua
# Processing Record 19 of Set 4 | tarrafal
# Processing Record 20 of Set 4 | beyneu
# Processing Record 21 of Set 4 | vega de alatorre
# Processing Record 22 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 23 of Set 4 | sistranda
# Processing Record 24 of Set 4 | perth
# Processing Record 25 of Set 4 | cabedelo
# Processing Record 26 of Set 4 | korla
# Processing Record 27 of Set 4 | liverpool
# Processing Record 28 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 4 | lapovo
# Processing Record 30 of Set 4 | omsukchan
# Processing Record 31 of Set 4 | maloshuyka
# City not found. Skipping...
# Processing Record 32 of Set 4 | cayenne
# Processing Record 33 of Set 4 | palmer
# Processing Record 34 of Set 4 | itoman
# Processing Record 35 of Set 4 | taltal
# Processing Record 36 of Set 4 | avera
# Processing Record 37 of Set 4 | yuci
# Processing Record 38 of Set 4 | iralaya
# Processing Record 39 of Set 4 | gao
# Processing Record 40 of Set 4 | san patricio
# Processing Record 41 of Set 4 | viedma
# Processing Record 42 of Set 4 | omboue
# Processing Record 43 of Set 4 | marawi
# Processing Record 44 of Set 4 | taoudenni
# Processing Record 45 of Set 4 | killybegs
# Processing Record 46 of Set 4 | lorengau
# Processing Record 47 of Set 4 | erenhot
# Processing Record 48 of Set 4 | bulungu
# Processing Record 49 of Set 4 | yar-sale
# Processing Record 50 of Set 4 | klaksvik
# Processing Record 1 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 2 of Set 5 | nantucket
# Processing Record 3 of Set 5 | sao filipe
# Processing Record 4 of Set 5 | katsuura
# Processing Record 5 of Set 5 | dingle
# Processing Record 6 of Set 5 | maragogi
# Processing Record 7 of Set 5 | geraldton
# Processing Record 8 of Set 5 | cape town
# Processing Record 9 of Set 5 | meybod
# Processing Record 10 of Set 5 | kavaratti
# Processing Record 11 of Set 5 | shanghai
# Processing Record 12 of Set 5 | porto santo
# Processing Record 13 of Set 5 | lubango
# Processing Record 14 of Set 5 | sines
# Processing Record 15 of Set 5 | yaan
# Processing Record 16 of Set 5 | alice springs
# Processing Record 17 of Set 5 | villazon
# Processing Record 18 of Set 5 | nome
# Processing Record 19 of Set 5 | cherskiy
# Processing Record 20 of Set 5 | dukat
# Processing Record 21 of Set 5 | arraial do cabo
# Processing Record 22 of Set 5 | half moon bay
# Processing Record 23 of Set 5 | matara
# Processing Record 24 of Set 5 | itarema
# Processing Record 25 of Set 5 | nuuk
# Processing Record 26 of Set 5 | mokobeng
# Processing Record 27 of Set 5 | rawson
# Processing Record 28 of Set 5 | castro
# Processing Record 29 of Set 5 | cabo san lucas
# Processing Record 30 of Set 5 | nachingwea
# Processing Record 31 of Set 5 | haines junction
# Processing Record 32 of Set 5 | huarmey
# Processing Record 33 of Set 5 | daru
# Processing Record 34 of Set 5 | caxito
# Processing Record 35 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 5 | kaduna
# Processing Record 37 of Set 5 | cedar city
# Processing Record 38 of Set 5 | cartagena
# Processing Record 39 of Set 5 | najran
# Processing Record 40 of Set 5 | kot samaba
# Processing Record 41 of Set 5 | takoradi
# Processing Record 42 of Set 5 | quatre cocos
# Processing Record 43 of Set 5 | turayf
# Processing Record 44 of Set 5 | kaeo
# Processing Record 45 of Set 5 | manoel urbano
# Processing Record 46 of Set 5 | sosua
# Processing Record 47 of Set 5 | lebu
# Processing Record 48 of Set 5 | tommot
# Processing Record 49 of Set 5 | lata
# Processing Record 50 of Set 5 | chokurdakh
# Processing Record 1 of Set 6 | cheney
# Processing Record 2 of Set 6 | havelock
# Processing Record 3 of Set 6 | jalu
# Processing Record 4 of Set 6 | galle
# Processing Record 5 of Set 6 | catamarca
# Processing Record 6 of Set 6 | ponta do sol
# Processing Record 7 of Set 6 | vostok
# Processing Record 8 of Set 6 | samana
# Processing Record 9 of Set 6 | alvarado
# Processing Record 10 of Set 6 | mount gambier
# Processing Record 11 of Set 6 | san cristobal
# Processing Record 12 of Set 6 | davila
# Processing Record 13 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 6 | shambu
# Processing Record 15 of Set 6 | chara
# Processing Record 16 of Set 6 | chake chake
# Processing Record 17 of Set 6 | padilla
# Processing Record 18 of Set 6 | ajdabiya
# Processing Record 19 of Set 6 | loviisa
# Processing Record 20 of Set 6 | dungarpur
# Processing Record 21 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 22 of Set 6 | yangmei
# Processing Record 23 of Set 6 | bambous virieux

# %%
len(city_data)
# Out:
# 701

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Busselton -33.65  115.33     64.99        65          97        3.96
# 1      Wewak  -3.55  143.63     85.23        68          73        6.15
# 2   Belmonte -15.86  -38.88     66.20        93          75        8.05
# 3    Mataura -46.19  168.86     55.99        64          25        8.99
# 4  Tambopata -12.73  -69.18     69.67        60          32        2.66
# 5       Aksu  41.12   80.26     51.85        39           1        1.32
# 6   Victoria  22.29  114.16     84.99        56          86        1.01
# 7      Vaini -21.20 -175.20     78.80        83          40       10.29
# 8  Saquarema -22.92  -42.51     64.74        77          16       10.40
# 9      Kapaa  22.08 -159.32     73.99       100          90        9.17
#
#   Country                 Date
# 0      AU  2020-11-02 05:08:04
# 1      PG  2020-11-02 05:08:05
# 2      BR  2020-11-02 05:08:05
# 3      NZ  2020-11-02 05:08:05
# 4      PE  2020-11-02 05:04:55
# 5      CN  2020-11-02 05:09:49
# 6      HK  2020-11-02 05:06:54
# 7      TO  2020-11-02 05:09:49
# 8      BR  2020-11-02 05:08:06
# 9      US  2020-11-02 05:08:06
