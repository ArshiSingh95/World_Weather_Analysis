# %%
#Import dependecies 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
from citipy import citipy

# %%
# Use the citipy module to determine city based on latitude and longitude.

# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# cockburn town tc
# gat ly
# parvatsar in
# punta arenas cl
# saint george bm

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=77ac22f8186988d8f5bc0eb580c03667

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=77ac22f8186988d8f5bc0eb580c03667&q=Boston

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [404]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.06,"lat":42.36},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04n"}],"base":"stations","main":{"temp":45.91,"feels_like":41.25,"temp_min":44.6,"temp_max":46.99,"pressure":1015,"humidity":93},"visibility":10000,"wind":{"speed":5.82,"deg":230},"clouds":{"all":90},"dt":1603942647,"sys":{"type":1,"id":3486,"country":"US","sunrise":1603883585,"sunset":1603921361},"timezone":-14400,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 45.91,
#   'feels_like': 41.25,
#   'temp_min': 44.6,
#   'temp_max': 46.99,
#   'pressure': 1015,
#   'humidity': 93},
#  'visibility': 10000,
#  'wind': {'speed': 5.82, 'deg': 230},
#  'clouds': {'all': 90},
#  'dt': 1603942647,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1603883585,
#   'sunset': 1603921361},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 45.91,
#   'feels_like': 41.25,
#   'temp_min': 44.6,
#   'temp_max': 46.99,
#   'pressure': 1015,
#   'humidity': 93},
#  'visibility': 10000,
#  'wind': {'speed': 5.82, 'deg': 230},
#  'clouds': {'all': 90},
#  'dt': 1603942443,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1603883585,
#   'sunset': 1603921361},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.36 -71.06 46.99 93 90 5.82

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2020-10-29 03:34:03'

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 598

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
            print("City not found. Skipping...")
            pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yellowknife
# Processing Record 2 of Set 1 | brae
# Processing Record 3 of Set 1 | jamestown
# Processing Record 4 of Set 1 | moose factory
# Processing Record 5 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | yongchang
# Processing Record 8 of Set 1 | kodiak
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | isangel
# Processing Record 11 of Set 1 | barrow
# Processing Record 12 of Set 1 | gamba
# Processing Record 13 of Set 1 | pombas
# Processing Record 14 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 1 | zyryanka
# Processing Record 16 of Set 1 | nikolskoye
# Processing Record 17 of Set 1 | atuona
# Processing Record 18 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 1 | elverum
# Processing Record 20 of Set 1 | khilok
# Processing Record 21 of Set 1 | forestville
# Processing Record 22 of Set 1 | orissaare
# Processing Record 23 of Set 1 | lagunas
# Processing Record 24 of Set 1 | tual
# Processing Record 25 of Set 1 | faridan
# City not found. Skipping...
# Processing Record 26 of Set 1 | pacifica
# Processing Record 27 of Set 1 | nome
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | new norfolk
# Processing Record 30 of Set 1 | pokhara
# Processing Record 31 of Set 1 | qandala
# Processing Record 32 of Set 1 | yar-sale
# Processing Record 33 of Set 1 | san andres
# Processing Record 34 of Set 1 | pampas
# Processing Record 35 of Set 1 | longyearbyen
# Processing Record 36 of Set 1 | takoradi
# Processing Record 37 of Set 1 | kavieng
# Processing Record 38 of Set 1 | usinsk
# Processing Record 39 of Set 1 | ponta delgada
# Processing Record 40 of Set 1 | kaniama
# Processing Record 41 of Set 1 | nossa senhora do socorro
# Processing Record 42 of Set 1 | harper
# Processing Record 43 of Set 1 | pudozh
# Processing Record 44 of Set 1 | ushuaia
# Processing Record 45 of Set 1 | lasa
# Processing Record 46 of Set 1 | pringsewu
# Processing Record 47 of Set 1 | obihiro
# Processing Record 48 of Set 1 | sorland
# Processing Record 49 of Set 1 | esperance
# Processing Record 50 of Set 1 | mataura
# Processing Record 1 of Set 2 | fairbanks
# Processing Record 2 of Set 2 | dom pedrito
# Processing Record 3 of Set 2 | sidhauli
# Processing Record 4 of Set 2 | bahia blanca
# Processing Record 5 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 6 of Set 2 | cabra
# Processing Record 7 of Set 2 | butaritari
# Processing Record 8 of Set 2 | acapulco
# Processing Record 9 of Set 2 | samarai
# Processing Record 10 of Set 2 | dingle
# Processing Record 11 of Set 2 | erenhot
# Processing Record 12 of Set 2 | albany
# Processing Record 13 of Set 2 | ambilobe
# Processing Record 14 of Set 2 | birin
# Processing Record 15 of Set 2 | hithadhoo
# Processing Record 16 of Set 2 | tuktoyaktuk
# Processing Record 17 of Set 2 | kruisfontein
# Processing Record 18 of Set 2 | tiksi
# Processing Record 19 of Set 2 | bluff
# Processing Record 20 of Set 2 | provideniya
# Processing Record 21 of Set 2 | isla vista
# Processing Record 22 of Set 2 | port blair
# Processing Record 23 of Set 2 | dombarovskiy
# Processing Record 24 of Set 2 | saldanha
# Processing Record 25 of Set 2 | nago
# Processing Record 26 of Set 2 | hasaki
# Processing Record 27 of Set 2 | loreto
# Processing Record 28 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 2 | kawalu
# Processing Record 30 of Set 2 | petrovsk-zabaykalskiy
# Processing Record 31 of Set 2 | ahipara
# Processing Record 32 of Set 2 | antalaha
# Processing Record 33 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 2 | cidreira
# Processing Record 35 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 2 | hilo
# Processing Record 37 of Set 2 | henties bay
# Processing Record 38 of Set 2 | alice springs
# Processing Record 39 of Set 2 | hambantota
# Processing Record 40 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 2 | xingcheng
# Processing Record 43 of Set 2 | huanan
# Processing Record 44 of Set 2 | lagoa
# Processing Record 45 of Set 2 | felanitx
# Processing Record 46 of Set 2 | manggar
# Processing Record 47 of Set 2 | mount isa
# Processing Record 48 of Set 2 | vanimo
# Processing Record 49 of Set 2 | alofi
# Processing Record 50 of Set 2 | saint-philippe
# Processing Record 1 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 3 | bilibino
# Processing Record 3 of Set 3 | villamontes
# Processing Record 4 of Set 3 | qaanaaq
# Processing Record 5 of Set 3 | lebu
# Processing Record 6 of Set 3 | port alfred
# Processing Record 7 of Set 3 | tripoli
# Processing Record 8 of Set 3 | mamallapuram
# Processing Record 9 of Set 3 | rio grande
# Processing Record 10 of Set 3 | kovdor
# Processing Record 11 of Set 3 | kang
# Processing Record 12 of Set 3 | acajutla
# Processing Record 13 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 14 of Set 3 | hobart
# Processing Record 15 of Set 3 | avarua
# Processing Record 16 of Set 3 | nemuro
# Processing Record 17 of Set 3 | vardo
# Processing Record 18 of Set 3 | egvekinot
# Processing Record 19 of Set 3 | davila
# Processing Record 20 of Set 3 | krasnogorskiy
# Processing Record 21 of Set 3 | matara
# Processing Record 22 of Set 3 | atasu
# Processing Record 23 of Set 3 | haines junction
# Processing Record 24 of Set 3 | carnarvon
# Processing Record 25 of Set 3 | victoria
# Processing Record 26 of Set 3 | guerrero negro
# Processing Record 27 of Set 3 | magadan
# Processing Record 28 of Set 3 | cape town
# Processing Record 29 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 3 | port hardy
# Processing Record 31 of Set 3 | zhezkazgan
# Processing Record 32 of Set 3 | bethel
# Processing Record 33 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 3 | vaini
# Processing Record 35 of Set 3 | pemangkat
# Processing Record 36 of Set 3 | ayagoz
# Processing Record 37 of Set 3 | geraldton
# Processing Record 38 of Set 3 | vostok
# Processing Record 39 of Set 3 | hanzhong
# Processing Record 40 of Set 3 | korla
# Processing Record 41 of Set 3 | berdigestyakh
# Processing Record 42 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 3 | birjand
# Processing Record 44 of Set 3 | hermanus
# Processing Record 45 of Set 3 | amapa
# Processing Record 46 of Set 3 | chokurdakh
# Processing Record 47 of Set 3 | umm durman
# City not found. Skipping...
# Processing Record 48 of Set 3 | coihaique
# Processing Record 49 of Set 3 | san quintin
# Processing Record 50 of Set 3 | san luis
# Processing Record 1 of Set 4 | arraial do cabo
# Processing Record 2 of Set 4 | anadyr
# Processing Record 3 of Set 4 | tuatapere
# Processing Record 4 of Set 4 | iqaluit
# Processing Record 5 of Set 4 | touros
# Processing Record 6 of Set 4 | merauke
# Processing Record 7 of Set 4 | caravelas
# Processing Record 8 of Set 4 | aklavik
# Processing Record 9 of Set 4 | upata
# Processing Record 10 of Set 4 | mount gambier
# Processing Record 11 of Set 4 | yanchukan
# City not found. Skipping...
# Processing Record 12 of Set 4 | college
# Processing Record 13 of Set 4 | macapa
# Processing Record 14 of Set 4 | saskylakh
# Processing Record 15 of Set 4 | half moon bay
# Processing Record 16 of Set 4 | puerto ayora
# Processing Record 17 of Set 4 | bulaevo
# Processing Record 18 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 4 | dikson
# Processing Record 20 of Set 4 | severo-kurilsk
# Processing Record 21 of Set 4 | atbasar
# Processing Record 22 of Set 4 | juneau
# Processing Record 23 of Set 4 | san patricio
# Processing Record 24 of Set 4 | manokwari
# Processing Record 25 of Set 4 | libreville
# Processing Record 26 of Set 4 | pacific grove
# Processing Record 27 of Set 4 | lorengau
# Processing Record 28 of Set 4 | sibolga
# Processing Record 29 of Set 4 | santa rosalia
# Processing Record 30 of Set 4 | avera
# Processing Record 31 of Set 4 | leningradskiy
# Processing Record 32 of Set 4 | the valley
# Processing Record 33 of Set 4 | mar del plata
# Processing Record 34 of Set 4 | kettering
# Processing Record 35 of Set 4 | flinders
# Processing Record 36 of Set 4 | la puebla del rio
# Processing Record 37 of Set 4 | plettenberg bay
# Processing Record 38 of Set 4 | beringovskiy
# Processing Record 39 of Set 4 | byron bay
# Processing Record 40 of Set 4 | khatanga
# Processing Record 41 of Set 4 | djibo
# Processing Record 42 of Set 4 | pevek
# Processing Record 43 of Set 4 | kamaishi
# Processing Record 44 of Set 4 | mon
# Processing Record 45 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 46 of Set 4 | airai
# Processing Record 47 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 4 | bam
# Processing Record 49 of Set 4 | kerman
# Processing Record 50 of Set 4 | muros
# Processing Record 1 of Set 5 | kapaa
# Processing Record 2 of Set 5 | khandyga
# Processing Record 3 of Set 5 | bengkulu
# Processing Record 4 of Set 5 | bury saint edmunds
# City not found. Skipping...
# Processing Record 5 of Set 5 | temaraia
# City not found. Skipping...
# Processing Record 6 of Set 5 | vila velha
# Processing Record 7 of Set 5 | santa cruz
# Processing Record 8 of Set 5 | tasiilaq
# Processing Record 9 of Set 5 | madhoganj
# Processing Record 10 of Set 5 | vanavara
# Processing Record 11 of Set 5 | katobu
# Processing Record 12 of Set 5 | pochutla
# Processing Record 13 of Set 5 | sfantu gheorghe
# Processing Record 14 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 5 | riyadh
# Processing Record 16 of Set 5 | chernyshevskiy
# Processing Record 17 of Set 5 | ewa beach
# Processing Record 18 of Set 5 | nakonde
# Processing Record 19 of Set 5 | pahrump
# Processing Record 20 of Set 5 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 21 of Set 5 | moyale
# Processing Record 22 of Set 5 | bredasdorp
# Processing Record 23 of Set 5 | ponta do sol
# Processing Record 24 of Set 5 | aparecida do taboado
# Processing Record 25 of Set 5 | canutama
# Processing Record 26 of Set 5 | fortuna
# Processing Record 27 of Set 5 | cherskiy
# Processing Record 28 of Set 5 | laguna
# Processing Record 29 of Set 5 | pisco
# Processing Record 30 of Set 5 | plonsk
# Processing Record 31 of Set 5 | kota kinabalu
# Processing Record 32 of Set 5 | yoichi
# Processing Record 33 of Set 5 | bonthe
# Processing Record 34 of Set 5 | garissa
# Processing Record 35 of Set 5 | hofn
# Processing Record 36 of Set 5 | moron
# Processing Record 37 of Set 5 | derzhavinsk
# Processing Record 38 of Set 5 | aykhal
# Processing Record 39 of Set 5 | ndele
# Processing Record 40 of Set 5 | faanui
# Processing Record 41 of Set 5 | tautira
# Processing Record 42 of Set 5 | sitka
# Processing Record 43 of Set 5 | lakes entrance
# Processing Record 44 of Set 5 | karamea
# City not found. Skipping...
# Processing Record 45 of Set 5 | san cristobal
# Processing Record 46 of Set 5 | savannakhet
# Processing Record 47 of Set 5 | machico
# Processing Record 48 of Set 5 | saint pete beach
# Processing Record 49 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 5 | ust-karsk
# Processing Record 1 of Set 6 | jiwani
# Processing Record 2 of Set 6 | baykit
# Processing Record 3 of Set 6 | ndola
# Processing Record 4 of Set 6 | tiznit
# Processing Record 5 of Set 6 | georgetown
# Processing Record 6 of Set 6 | kampene
# Processing Record 7 of Set 6 | taoudenni
# Processing Record 8 of Set 6 | sao filipe
# Processing Record 9 of Set 6 | qaqortoq
# Processing Record 10 of Set 6 | mandalgovi
# Processing Record 11 of Set 6 | malakal
# Processing Record 12 of Set 6 | sokoto
# Processing Record 13 of Set 6 | rosarito
# Processing Record 14 of Set 6 | sola
# Processing Record 15 of Set 6 | halmstad
# Processing Record 16 of Set 6 | castro
# Processing Record 17 of Set 6 | westport
# Processing Record 18 of Set 6 | imeni poliny osipenko
# Processing Record 19 of Set 6 | grand gaube
# Processing Record 20 of Set 6 | deh rawud
# City not found. Skipping...
# Processing Record 21 of Set 6 | porto novo
# Processing Record 22 of Set 6 | mayo
# Processing Record 23 of Set 6 | beira
# Processing Record 24 of Set 6 | makakilo city
# Processing Record 25 of Set 6 | bandarbeyla
# Processing Record 26 of Set 6 | goderich
# Processing Record 27 of Set 6 | banda aceh
# Processing Record 28 of Set 6 | ribeira grande
# Processing Record 29 of Set 6 | lazaro cardenas
# Processing Record 30 of Set 6 | nabire
# Processing Record 31 of Set 6 | zhigansk
# Processing Record 32 of Set 6 | sur
# Processing Record 33 of Set 6 | bodden town
# Processing Record 34 of Set 6 | belyy yar
# Processing Record 35 of Set 6 | phumi samraong
# City not found. Skipping...
# Processing Record 36 of Set 6 | pangnirtung
# Processing Record 37 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 38 of Set 6 | hamilton
# Processing Record 39 of Set 6 | lokosovo
# Processing Record 40 of Set 6 | mikuni
# Processing Record 41 of Set 6 | dubbo
# Processing Record 42 of Set 6 | olafsvik
# Processing Record 43 of Set 6 | chapais
# Processing Record 44 of Set 6 | udachnyy
# Processing Record 45 of Set 6 | la crosse
# Processing Record 46 of Set 6 | lewiston
# Processing Record 47 of Set 6 | mahebourg
# Processing Record 48 of Set 6 | cap malheureux
# Processing Record 49 of Set 6 | waddan
# Processing Record 50 of Set 6 | puerto leguizamo
# Processing Record 1 of Set 7 | nevelsk
# Processing Record 2 of Set 7 | southampton
# Processing Record 3 of Set 7 | talcahuano
# Processing Record 4 of Set 7 | teguise
# Processing Record 5 of Set 7 | paracuru
# Processing Record 6 of Set 7 | witu
# Processing Record 7 of Set 7 | thompson
# Processing Record 8 of Set 7 | godfrey
# Processing Record 9 of Set 7 | shitkino
# Processing Record 10 of Set 7 | ola
# Processing Record 11 of Set 7 | boende
# Processing Record 12 of Set 7 | volovo
# Processing Record 13 of Set 7 | abong mbang
# Processing Record 14 of Set 7 | bubaque
# Processing Record 15 of Set 7 | narrabri
# Processing Record 16 of Set 7 | vila franca do campo
# Processing Record 17 of Set 7 | great yarmouth
# Processing Record 18 of Set 7 | yeppoon
# Processing Record 19 of Set 7 | shelburne
# Processing Record 20 of Set 7 | hami
# Processing Record 21 of Set 7 | ulladulla
# Processing Record 22 of Set 7 | rawson
# Processing Record 23 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 24 of Set 7 | xining
# Processing Record 25 of Set 7 | ilam
# Processing Record 26 of Set 7 | kiruna
# Processing Record 27 of Set 7 | riverton
# Processing Record 28 of Set 7 | orichi
# Processing Record 29 of Set 7 | port elizabeth
# Processing Record 30 of Set 7 | lee
# Processing Record 31 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 7 | skibbereen
# Processing Record 33 of Set 7 | husavik
# Processing Record 34 of Set 7 | chuy
# Processing Record 35 of Set 7 | envira
# Processing Record 36 of Set 7 | orange
# Processing Record 37 of Set 7 | pombia
# Processing Record 38 of Set 7 | union
# Processing Record 39 of Set 7 | chicama
# Processing Record 40 of Set 7 | bambous virieux
# Processing Record 41 of Set 7 | tilichiki
# Processing Record 42 of Set 7 | saint anthony
# Processing Record 43 of Set 7 | ancud
# Processing Record 44 of Set 7 | luderitz
# Processing Record 45 of Set 7 | manuk mangkaw
# Processing Record 46 of Set 7 | san carlos de bariloche
# Processing Record 47 of Set 7 | butte
# Processing Record 48 of Set 7 | hobyo
# Processing Record 49 of Set 7 | pouembout
# Processing Record 50 of Set 7 | mahaicony
# City not found. Skipping...
# Processing Record 1 of Set 8 | viedma
# Processing Record 2 of Set 8 | bosaso
# Processing Record 3 of Set 8 | ishigaki
# Processing Record 4 of Set 8 | bentiu
# Processing Record 5 of Set 8 | palora
# Processing Record 6 of Set 8 | saurimo
# Processing Record 7 of Set 8 | marsabit
# Processing Record 8 of Set 8 | grand-santi
# Processing Record 9 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 10 of Set 8 | la ronge
# Processing Record 11 of Set 8 | camabatela
# Processing Record 12 of Set 8 | nipawin
# Processing Record 13 of Set 8 | darhan
# Processing Record 14 of Set 8 | luwuk
# Processing Record 15 of Set 8 | hovd
# Processing Record 16 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 17 of Set 8 | karauzyak
# City not found. Skipping...
# Processing Record 18 of Set 8 | verkhoyansk
# Processing Record 19 of Set 8 | zandvoort
# Processing Record 20 of Set 8 | srednekolymsk
# Processing Record 21 of Set 8 | wamba
# Processing Record 22 of Set 8 | suda
# Processing Record 23 of Set 8 | lumding
# Processing Record 24 of Set 8 | arvika
# Processing Record 25 of Set 8 | waingapu
# Processing Record 26 of Set 8 | dunedin
# Processing Record 27 of Set 8 | ampanihy
# Processing Record 28 of Set 8 | pucallpa
# Processing Record 29 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 31 of Set 8 | turukhansk
# Processing Record 32 of Set 8 | dadri
# Processing Record 33 of Set 8 | nola
# Processing Record 34 of Set 8 | luganville
# Processing Record 35 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 36 of Set 8 | krasnoselkup
# Processing Record 37 of Set 8 | kamenka
# Processing Record 38 of Set 8 | troitskoye
# Processing Record 39 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 8 | montepuez
# Processing Record 41 of Set 8 | katsuura
# Processing Record 42 of Set 8 | lakhnadon
# Processing Record 43 of Set 8 | coshocton
# Processing Record 44 of Set 8 | pershotravneve
# Processing Record 45 of Set 8 | east london
# Processing Record 46 of Set 8 | naryan-mar
# Processing Record 47 of Set 8 | atlantic beach
# Processing Record 48 of Set 8 | norton
# Processing Record 49 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 50 of Set 8 | kunashak
# Processing Record 1 of Set 9 | alfreton
# Processing Record 2 of Set 9 | nanortalik
# Processing Record 3 of Set 9 | ivanishchi
# Processing Record 4 of Set 9 | la union
# Processing Record 5 of Set 9 | flin flon
# Processing Record 6 of Set 9 | sim
# Processing Record 7 of Set 9 | saravena
# Processing Record 8 of Set 9 | gumdag
# Processing Record 9 of Set 9 | souillac
# Processing Record 10 of Set 9 | kangaatsiaq
# Processing Record 11 of Set 9 | igarape-acu
# City not found. Skipping...
# Processing Record 12 of Set 9 | los llanos de aridane
# Processing Record 13 of Set 9 | tiarei
# Processing Record 14 of Set 9 | buala
# Processing Record 15 of Set 9 | amazar
# Processing Record 16 of Set 9 | talnakh
# Processing Record 17 of Set 9 | evensk
# Processing Record 18 of Set 9 | mumford
# Processing Record 19 of Set 9 | itarema
# Processing Record 20 of Set 9 | birao
# Processing Record 21 of Set 9 | menongue
# Processing Record 22 of Set 9 | narsaq
# Processing Record 23 of Set 9 | aloleng
# Processing Record 24 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 9 | komsomolskiy
# Processing Record 26 of Set 9 | sumbuya
# Processing Record 27 of Set 9 | vreed en hoop
# City not found. Skipping...
# Processing Record 28 of Set 9 | bereda
# Processing Record 29 of Set 9 | patitirion
# Processing Record 30 of Set 9 | yulara
# Processing Record 31 of Set 9 | elizabeth city
# Processing Record 32 of Set 9 | tazovskiy
# Processing Record 33 of Set 9 | shingu
# Processing Record 34 of Set 9 | alingsas
# Processing Record 35 of Set 9 | faya
# Processing Record 36 of Set 9 | martinopolis
# Processing Record 37 of Set 9 | agva
# City not found. Skipping...
# Processing Record 38 of Set 9 | ketchikan
# Processing Record 39 of Set 9 | kabanjahe
# Processing Record 40 of Set 9 | gurgan
# City not found. Skipping...
# Processing Record 41 of Set 9 | nouadhibou
# Processing Record 42 of Set 9 | waipawa
# Processing Record 43 of Set 9 | kavaratti
# Processing Record 44 of Set 9 | ilulissat
# Processing Record 45 of Set 9 | saryg-sep
# Processing Record 46 of Set 9 | honningsvag
# Processing Record 47 of Set 9 | camacha
# Processing Record 48 of Set 9 | puerto vallarta
# Processing Record 49 of Set 9 | bonavista
# Processing Record 50 of Set 9 | homer
# Processing Record 1 of Set 10 | bilma
# Processing Record 2 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 3 of Set 10 | salalah
# Processing Record 4 of Set 10 | moree
# Processing Record 5 of Set 10 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 6 of Set 10 | olinda
# Processing Record 7 of Set 10 | kon tum
# Processing Record 8 of Set 10 | sao joao da barra
# Processing Record 9 of Set 10 | baturaja
# Processing Record 10 of Set 10 | kolyshley
# Processing Record 11 of Set 10 | port augusta
# Processing Record 12 of Set 10 | medford
# Processing Record 13 of Set 10 | beloha
# Processing Record 14 of Set 10 | pyay
# Processing Record 15 of Set 10 | saint-pierre
# Processing Record 16 of Set 10 | tres arroyos
# Processing Record 17 of Set 10 | agadez
# Processing Record 18 of Set 10 | breyten
# Processing Record 19 of Set 10 | sisimiut
# Processing Record 20 of Set 10 | mizdah
# Processing Record 21 of Set 10 | russellville
# Processing Record 22 of Set 10 | palu
# Processing Record 23 of Set 10 | singapore
# Processing Record 24 of Set 10 | innisfail
# Processing Record 25 of Set 10 | duku
# Processing Record 26 of Set 10 | kysyl-syr
# Processing Record 27 of Set 10 | eureka
# Processing Record 28 of Set 10 | kenai
# Processing Record 29 of Set 10 | luanda
# Processing Record 30 of Set 10 | naze
# Processing Record 31 of Set 10 | clyde river
# Processing Record 32 of Set 10 | akyab
# Processing Record 33 of Set 10 | hirara
# Processing Record 34 of Set 10 | sistranda
# Processing Record 35 of Set 10 | illapel
# Processing Record 36 of Set 10 | uyskoye
# Processing Record 37 of Set 10 | brownsville
# Processing Record 38 of Set 10 | fallon
# Processing Record 39 of Set 10 | nakanojo
# Processing Record 40 of Set 10 | klaksvik
# Processing Record 41 of Set 10 | norman wells
# Processing Record 42 of Set 10 | nizwa
# Processing Record 43 of Set 10 | belaya gora
# Processing Record 44 of Set 10 | sao joao del rei
# Processing Record 45 of Set 10 | necochea
# Processing Record 46 of Set 10 | eregli
# Processing Record 47 of Set 10 | karratha
# Processing Record 48 of Set 10 | torbay
# Processing Record 49 of Set 10 | berezovyy
# Processing Record 50 of Set 10 | sioux lookout
# Processing Record 1 of Set 11 | fukue
# Processing Record 2 of Set 11 | el tigre
# Processing Record 3 of Set 11 | russell
# Processing Record 4 of Set 11 | sompeta
# Processing Record 5 of Set 11 | taburao
# City not found. Skipping...
# Processing Record 6 of Set 11 | vengerovo
# Processing Record 7 of Set 11 | honiara
# Processing Record 8 of Set 11 | quelimane
# Processing Record 9 of Set 11 | devonport
# Processing Record 10 of Set 11 | lavrentiya
# Processing Record 11 of Set 11 | sobolevo
# Processing Record 12 of Set 11 | tacuarembo
# Processing Record 13 of Set 11 | poum
# Processing Record 14 of Set 11 | colwyn bay
# Processing Record 15 of Set 11 | kaitangata
# Processing Record 16 of Set 11 | novoilinskiy
# City not found. Skipping...
# Processing Record 17 of Set 11 | kissing
# Processing Record 18 of Set 11 | nalut
# Processing Record 19 of Set 11 | santa marinella
# Processing Record 20 of Set 11 | jawar
# Processing Record 21 of Set 11 | puerto narino
# Processing Record 22 of Set 11 | yanam
# Processing Record 23 of Set 11 | jieshi
# Processing Record 24 of Set 11 | ipixuna
# Processing Record 25 of Set 11 | dali
# Processing Record 26 of Set 11 | teneguiban
# City not found. Skipping...
# Processing Record 27 of Set 11 | humaita
# Processing Record 28 of Set 11 | cayenne
# Processing Record 29 of Set 11 | auki
# Processing Record 30 of Set 11 | lompoc
# Processing Record 31 of Set 11 | thunder bay
# Processing Record 32 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 11 | ormara
# Processing Record 34 of Set 11 | cooma
# Processing Record 35 of Set 11 | namatanai
# Processing Record 36 of Set 11 | sennoy
# Processing Record 37 of Set 11 | pierre
# Processing Record 38 of Set 11 | alyangula
# Processing Record 39 of Set 11 | iquique
# Processing Record 40 of Set 11 | portree
# Processing Record 41 of Set 11 | coahuayana
# Processing Record 42 of Set 11 | huarmey
# Processing Record 43 of Set 11 | red wing
# Processing Record 44 of Set 11 | denpasar
# Processing Record 45 of Set 11 | miram shah
# Processing Record 46 of Set 11 | boras
# Processing Record 47 of Set 11 | lamu
# Processing Record 48 of Set 11 | aripuana
# Processing Record 49 of Set 11 | bemidji
# Processing Record 50 of Set 11 | kuytun
# Processing Record 1 of Set 12 | linxia
# Processing Record 2 of Set 12 | waterloo
# Processing Record 3 of Set 12 | sarh
# Processing Record 4 of Set 12 | sambava
# Processing Record 5 of Set 12 | panzhihua
# Processing Record 6 of Set 12 | bathsheba
# Processing Record 7 of Set 12 | port-gentil
# Processing Record 8 of Set 12 | yumen
# Processing Record 9 of Set 12 | kalmunai
# Processing Record 10 of Set 12 | loukhi
# Processing Record 11 of Set 12 | lalmohan
# Processing Record 12 of Set 12 | kiunga
# Processing Record 13 of Set 12 | atambua
# Processing Record 14 of Set 12 | codrington
# Processing Record 15 of Set 12 | kindersley
# Processing Record 16 of Set 12 | burnie
# Processing Record 17 of Set 12 | norwalk
# Processing Record 18 of Set 12 | gurgentepe
# Processing Record 19 of Set 12 | sumbawa
# City not found. Skipping...
# Processing Record 20 of Set 12 | portland
# Processing Record 21 of Set 12 | newport
# Processing Record 22 of Set 12 | matagami
# Processing Record 23 of Set 12 | ayr
# Processing Record 24 of Set 12 | lagoa vermelha
# Processing Record 25 of Set 12 | jiuquan
# Processing Record 26 of Set 12 | ahuimanu
# Processing Record 27 of Set 12 | machali
# Processing Record 28 of Set 12 | saint combs
# City not found. Skipping...
# Processing Record 29 of Set 12 | viet tri
# Processing Record 30 of Set 12 | inverell
# Processing Record 31 of Set 12 | solnechnyy
# Processing Record 32 of Set 12 | port lincoln
# Processing Record 33 of Set 12 | varhaug
# Processing Record 34 of Set 12 | rockhampton
# Processing Record 35 of Set 12 | balimo
# City not found. Skipping...
# Processing Record 36 of Set 12 | wawa
# Processing Record 37 of Set 12 | nurota
# Processing Record 38 of Set 12 | ouargaye
# Processing Record 39 of Set 12 | mazatlan
# Processing Record 40 of Set 12 | rohri
# Processing Record 41 of Set 12 | lugovoy
# Processing Record 42 of Set 12 | zaysan
# Processing Record 43 of Set 12 | kyrnasivka
# Processing Record 44 of Set 12 | filadelfia
# Processing Record 45 of Set 12 | fairlie
# Processing Record 46 of Set 12 | haverfordwest
# Processing Record 47 of Set 12 | mapimi
# Processing Record 48 of Set 12 | chute-aux-outardes
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Yellowknife  62.46 -114.35     21.20        85          90       11.41
# 1           Brae  60.40   -1.35     50.00        87          88        8.05
# 2      Jamestown  42.10  -79.24     42.01       100           1        3.36
# 3  Moose Factory  51.26  -80.61     24.80        79          90       11.41
# 4   Punta Arenas -53.15  -70.92     46.40        65          40       28.86
# 5      Yongchang  30.04  119.73     70.00        61          77        1.99
# 6         Kodiak  57.79 -152.41     39.20        64          90        6.93
# 7      Busselton -33.65  115.33     79.00        30           0        5.03
# 8        Isangel -19.55  169.27     82.40        61          75       11.41
# 9         Barrow  71.29 -156.79     21.20        79          90       10.29
#
#   Country                 Date
# 0      CA  2020-10-29 04:26:28
# 1      GB  2020-10-29 04:26:28
# 2      US  2020-10-29 04:26:28
# 3      CA  2020-10-29 04:26:28
# 4      CL  2020-10-29 04:26:29
# 5      CN  2020-10-29 04:26:29
# 6      US  2020-10-29 04:23:57
# 7      AU  2020-10-29 04:26:29
# 8      VU  2020-10-29 04:26:30
# 9      US  2020-10-29 04:26:30

# %%
city_data_df= city_data_df[["City","Country",'Date','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed']] 
city_data_df.head(10)
# Out:
#             City Country                 Date    Lat     Lng  Max Temp  \
# 0    Yellowknife      CA  2020-10-29 04:26:28  62.46 -114.35     21.20
# 1           Brae      GB  2020-10-29 04:26:28  60.40   -1.35     50.00
# 2      Jamestown      US  2020-10-29 04:26:28  42.10  -79.24     42.01
# 3  Moose Factory      CA  2020-10-29 04:26:28  51.26  -80.61     24.80
# 4   Punta Arenas      CL  2020-10-29 04:26:29 -53.15  -70.92     46.40
# 5      Yongchang      CN  2020-10-29 04:26:29  30.04  119.73     70.00
# 6         Kodiak      US  2020-10-29 04:23:57  57.79 -152.41     39.20
# 7      Busselton      AU  2020-10-29 04:26:29 -33.65  115.33     79.00
# 8        Isangel      VU  2020-10-29 04:26:30 -19.55  169.27     82.40
# 9         Barrow      US  2020-10-29 04:26:30  71.29 -156.79     21.20
#
#    Humidity  Cloudiness  Wind Speed
# 0        85          90       11.41
# 1        87          88        8.05
# 2       100           1        3.36
# 3        79          90       11.41
# 4        65          40       28.86
# 5        61          77        1.99
# 6        64          90        6.93
# 7        30           0        5.03
# 8        61          75       11.41
# 9        79          90       10.29

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %% [markdown]
# ## 6.2.7
